# %% [markdown]
# #       Automated E-D-A by (Pandas_profiling,sweetviz,dtale,Autoviz) on Student_performance Dataset

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408 at 0x28507892EB0>

# %%
#import pandas as pd                       #Automative EDA by using pandas profiling.
# !pip install pandas_profiling

# %%
from pandas_profiling import ProfileReport

# %%
Report=ProfileReport(pd.read_csv(r"C:\Users\Student\Downloads\student_performance\student_performance\data\student.csv"),explorative=True)

# %%
#!pip install sweetviz                                  #Automative EDA by using sweetviz.
import sweetviz as sz

# %%
Report_sweetviz=sz.analyze(pd.read_csv(r"C:\Users\Student\Downloads\student_performance\student_performance\data\student.csv"))

# %%
Report_sweetviz.show_html('Student_sweetviz.html')
# Out:
# Report Student_sweetviz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#!pip install dtale                      #Automative EDA by using dtale.
import dtale as dt

# %%
Report_dtale=dt.show(pd.read_csv(r "C:\Users\Student\Downloads\student_performance\student_performance\data\student.csv"))

# %%
#!pip install Autoviz                             #Automative EDA by using Autoviz.
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

#EDA using Autoviz
autoviz = AutoViz_Class().AutoViz(r"C:\Users\Student\Downloads\student_performance\student_performance\data\student.csv")
# Out:
# Shape of your Data Set loaded: (1000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_98703_row0_col0, #T_98703_row0_col4, #T_98703_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_98703_row0_col1, #T_98703_row0_col6, #T_98703_row1_col1, #T_98703_row1_col6, #T_98703_row2_col1, #T_98703_row2_col6, #T_98703_row3_col1, #T_98703_row3_col6, #T_98703_row4_col1, #T_98703_row4_col6, #T_98703_row5_col1, #T_98703_row5_col6, #T_98703_row6_col1, #T_98703_row6_col6, #T_98703_row7_col1, #T_98703_row7_col6 {
#   font-family: Segoe UI;
# }
# ...

# %%
#comment
#obeservation
import pandas as pd
import seaborn as sns
import numpy as np                          #Importing necessary libraries.
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Student\Downloads\student_performance\student_performance\data\student.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 8)

# %%
data['math score'].isnull                    #checking null values which are present in cells.
# Out:
# <bound method Series.isnull of 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 992, dtype: int64>

# %%
data.columns                            #Getting all features.
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#for i in data.columns:
    #if data[i].dtype=='O':
        #print(i)
num_col=[i for i in data.columns if data[i].dtypes!='O']      #seperating the numeric and categorical features.
cat_col=[i for i in data.columns if data[i].dtypes=='O']

# %%
data[cat_col]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
data.memory_usage()
# Out:
# Index                           128
# gender                         8000
# race/ethnicity                 8000
# parental level of education    8000
# lunch                          8000
# test preparation course        8000
# math score                     8000
# reading score                  8000
# writing score                  8000
# dtype: int64

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#data.duplicated().sum()
#data.nunique()
data['math score'].count()
# Out:
# 1000

# %%
from pandas_profiling import ProfileReport

# %%
#checking outliers in data['math score']
k=[]
m=[i for i in data['math score'] if i<=40 and i>=107]

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
data.cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
data.skew()
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
sns.distplot(x=data['writing score'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['average']= (data['math score']+data['reading score']+data['writing score'])/3

# %%
data['mean']= (data['math score']+data['reading score']+data['writing score']).mean()

# %%
data['median']= (data['math score']+data['reading score']+data['writing score']).median()

# %%
data['mode']=(data['math score']+data['reading score']+data['writing score']).mode()

# %%
data.groupby('gender')['math score','lunch'].count()
# Out:
#         math score  lunch
# gender
# female         518    518
# male           482    482

# %%
#we have to find number of students whoever having less than 30 marks
data[data['math score']<30].count()
# Out:
# gender                         14
# race/ethnicity                 14
# parental level of education    14
# lunch                          14
# test preparation course        14
# math score                     14
# reading score                  14
# writing score                  14
# average                        14
# mean                           14
# median                         14
# mode                            0
# dtype: int64

# %%
from scipy.stats import normaltest

# %%
normaltest(data['math score'])[1]    #if p-value > 0.05 then it is normally distributed
                                     #if p-value< 0.05 then it is non-normally distributed
# Out:
# 0.03389554376216317

# %%
sns.distplot(data['math score'])
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %%
sns.boxplot(data['math score'])
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
k
# Out:
# []

# %%
sns.boxplot(data['writing score'])
# Out:
# <AxesSubplot:xlabel='writing score'>

# %%
sns.boxplot(data['reading score'])
# Out:
# <AxesSubplot:xlabel='reading score'>

# %%
data.describe().T
# Out:
#                 count        mean           std      min         25%  \
# math score     1000.0   66.089000  1.516308e+01    0.000   57.000000
# reading score  1000.0   69.169000  1.460019e+01   17.000   59.000000
# writing score  1000.0   68.054000  1.519566e+01   10.000   57.750000
# average        1000.0   67.770667  1.425733e+01    9.000   58.333333
# mean           1000.0  203.312000  3.412312e-12  203.312  203.312000
# median         1000.0  205.000000  0.000000e+00  205.000  205.000000
# mode              1.0  204.000000           NaN  204.000  204.000000
#
#                       50%         75%      max
# math score      66.000000   77.000000  100.000
# reading score   70.000000   79.000000  100.000
# writing score   69.000000   79.000000  100.000
# average         68.333333   77.666667  100.000
# mean           203.312000  203.312000  203.312
# median         205.000000  205.000000  205.000
# mode           204.000000  204.000000  204.000

# %%
Q1=data['math score'].quantile(0.25)

# %%
Q3=data['math score'].quantile(0.75)

# %%
IQR=Q3-Q1
IQR
# Out:
# 20.0

# %%
lower_fence= Q1-1.5*IQR

# %%
higher_fence= Q3+1.5*IQR

# %%
lower_fence,higher_fence
# Out:
# (27.0, 107.0)

# %%
index=data[data['math score']<lower_fence].index

# %%
for i in index:
    print(data.drop(i,inplace=True))     #we removed outliers from the data.

# %%
 data.shape
# Out:
# (992, 12)

# %% [markdown]
# # Graphical Analysis

# %%
sns.countplot(data['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
 sns.countplot(data['race/ethnicity'])                          #we can check the balance of data.
                                                           #obeservation: this data is somewhat imbalance.
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'average', 'mean', 'median', 'mode'],
#       dtype='object')

# %%
sns.heatmap(data.corr(),annot=True,cmap='icefire',linewidths=15,linecolor='lightblue')
fig=plt.gcf()                                                              
fig.set_size_inches(8,8)                                 # we can plot heat map for checking correlation between variables.

plt.title('Correlation Between Variables',color='green',size=25)
# Out:
# Text(0.5, 1.0, 'Correlation Between Variables')

# %%
sns.pairplot(data)          #we can create pairplot for checking trend of data.

# %%
sns.set(rc={'figure.figsize':(15,5)})                 #Plot univariate or bivariate histograms to show distributions of datasets.
sns.histplot(data,shrink=.98,element="step")
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.boxenplot(data['math score'],color='green')
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
sns.boxplot(data['math score'],color='black')      #observation: there is no outliers w.r.t math_score feature.
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
sns.barplot(x=data['math score'],y=data['reading score'],saturation=0.15)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.ecdfplot(data)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %%
sns.swarmplot(x=data["math score"],y=data["reading score"],hue=data["gender"] )        #observation: math_score is positively correlated to readind_score irrespective of GENDER.
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>
